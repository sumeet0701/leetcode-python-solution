# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Removed oultiered.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  ID Project Code            PQ # PO / SO # ASN/DN #  \
# 0           0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8
# 1           1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85
# 2           2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14
# 3           3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50
# 4           4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55
#
#          Country Managed By  Fulfill Via Vendor INCO Term  ...  \
# 0  Côte d'Ivoire   PMO - US  Direct Drop              EXW  ...
# 1        Vietnam   PMO - US  Direct Drop              EXW  ...
# 2  Côte d'Ivoire   PMO - US  Direct Drop              FCA  ...
# 3        Vietnam   PMO - US  Direct Drop              EXW  ...
# 4        Vietnam   PMO - US  Direct Drop              EXW  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                       30.0               19.0           551.0      29.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9964 entries, 0 to 9963
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    9964 non-null   int64
#  1   ID                            9964 non-null   int64
#  2   Project Code                  9964 non-null   object
#  3   PQ #                          9964 non-null   object
#  4   PO / SO #                     9964 non-null   object
#  5   ASN/DN #                      9964 non-null   object
#  6   Country                       9964 non-null   object
#  7   Managed By                    9964 non-null   object
#  8   Fulfill Via                   9964 non-null   object
#  9   Vendor INCO Term              9964 non-null   object
#  10  Shipment Mode                 9964 non-null   object
#  11  PQ First Sent to Client Date  9964 non-null   object
# ...

# %%
# droping unwanted columns
df.drop(columns =['Unnamed: 0','ID'], inplace = True)

# %%
imp_num_cols =['']
